# %% [markdown]
# Normalization is a technique often applied as a part of data preparation for machine learning . The goal of normalization is to change the values of numeric cols in the dataset to use a common scale , without distorting differences in the ranges of values or losing information .
#
# Basically it is to get rid of  the units of the numeric cols and bring all the cols measuring to a common scale.
#
# normalization can be performed by following methods :-
# min max scaling
# mean normalization
# max absorb
# robust scaling

# %% [markdown]
# Min max scaling
#
# for a given col of values , xi = xi - xmin/ xmax- xmin
#
# where , xi = the value
#         xmax = the greatest value in the col
#         xmin = the smallest value in the col
#
#
# after this , the value of all the elements come between [0,1].

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('wine.csv', header = None , usecols = [0,1,2])
df.columns = ['Class label' , 'Alcohol' , 'Malic acid ']

# %%
df.head()
# Out:
#   Class label  Alcohol Malic acid
# 0       class  Alcohol  Malic acid
# 1           1    14.23        1.71
# 2           1     13.2        1.78
# 3           1    13.16        2.36
# 4           1    14.37        1.95

# %%
df
# Out:
#     Class label  Alcohol Malic acid
# 0         class  Alcohol  Malic acid
# 1             1    14.23        1.71
# 2             1     13.2        1.78
# 3             1    13.16        2.36
# 4             1    14.37        1.95
# ..          ...      ...         ...
# 174           3    13.71        5.65
# 175           3     13.4        3.91
# 176           3    13.27        4.28
# 177           3    13.17        2.59
# 178           3    14.13         4.1
#
# [179 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sns.kdeplot(df['Alcohol'] )
#       2
#       3
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
#    1682 color = _default_color(method, hue, color, kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/seaborn/_base.py:1084, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1079     if var_type not in allowed_types:
#    1080         err = (
#    1081             f"The {var} variable is {var_type}, but one of "
#    1082             f"{allowed_types} is required"
#    1083         )
# -> 1084         raise TypeError(err)
#    1086 # -- Get axis objects for each row in plot_data for type conversions and scaling
#    1088 facet_dim = {"x": "col", "y": "row"}
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %%
print(df.columns.tolist())
# Out:
# ['Class label', 'Alcohol', 'Malic acid ']

# %%
df = df[df['Class label'] != 'class']

# %%
color_dict = {'1':'red', '2':'blue', '3':'green'}
sns.scatterplot(data=df, x='Alcohol', y='Malic acid ', hue='Class label', palette=color_dict)
plt.show()

# %%
color_dict = {'1': 'red', '2': 'blue', '3': 'green'}
sns.scatterplot(data=df, x='Alcohol', y='Malic acid ', hue='Class label', palette=color_dict)
plt.show()

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df.drop('Class label' , axis = 1) , df['Class label'] , test_size  = 0.3 , random_state = 0 )
x_train.shape , x_test.shape
# Out:
# ((124, 2), (54, 2))

# %% [markdown]
# scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

#fit the scaler to the train set , it will learn parameters
scaler.fit(x_train ,y_train)

#transform train and test sets
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled = pd.DataFrame(x_train_scaled , columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled , columns = x_test.columns)

# %%
x_train.head()
# Out:
#     Alcohol Malic acid
# 23    13.71        1.86
# 109   12.22        1.29
# 176   13.27        4.28
# 146   13.16        3.57
# 72    13.86        1.51

# %%
x_train_scaled.head()
# Out:
#     Alcohol  Malic acid
# 0  0.720430     0.203782
# 1  0.319892     0.084034
# 2  0.602151     0.712185
# 3  0.572581     0.563025
# 4  0.760753     0.130252

# %%
x_test.head()
# Out:
#     Alcohol Malic acid
# 55    13.74        1.67
# 152   12.79        2.67
# 64    12.37        1.13
# 56    13.56        1.73
# 124   13.05         5.8

# %%
x_test_scaled.head()
# Out:
#     Alcohol  Malic acid
# 0  0.728495     0.163866
# 1  0.473118     0.373950
# 2  0.360215     0.050420
# 3  0.680108     0.176471
# 4  0.543011     1.031513

# %%
y_train.head() #not scaled.
# Out:
# 23     1
# 109    2
# 176    3
# 146    3
# 72     2
# Name: Class label, dtype: object
