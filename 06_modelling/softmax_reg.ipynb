# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , confusion_matrix
from sklearn.preprocessing import LabelEncoder
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
encoder = LabelEncoder()
df['species'] = encoder.fit_transform(df['species'])

# %%
df.sample(15)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 31            5.4          3.4           1.5          0.4        0
# 72            6.3          2.5           4.9          1.5        1
# 89            5.5          2.5           4.0          1.3        1
# 11            4.8          3.4           1.6          0.2        0
# 96            5.7          2.9           4.2          1.3        1
# 47            4.6          3.2           1.4          0.2        0
# 132           6.4          2.8           5.6          2.2        2
# 80            5.5          2.4           3.8          1.1        1
# 7             5.0          3.4           1.5          0.2        0
# 17            5.1          3.5           1.4          0.3        0
# 142           5.8          2.7           5.1          1.9        2
# 134           6.1          2.6           5.6          1.4        2
# 32            5.2          4.1           1.5          0.1        0
# 38            4.4          3.0           1.3          0.2        0
# 46            5.1          3.8           1.6          0.2        0

# %%
df = df[['sepal_length' , 'petal_length' , 'species']]

# %%
df
# Out:
#      sepal_length  petal_length  species
# 0             5.1           1.4        0
# 1             4.9           1.4        0
# 2             4.7           1.3        0
# 3             4.6           1.5        0
# 4             5.0           1.4        0
# ..            ...           ...      ...
# 145           6.7           5.2        2
# 146           6.3           5.0        2
# 147           6.5           5.2        2
# 148           6.2           5.4        2
# 149           5.9           5.1        2
#
# [150 rows x 3 columns]

# %%
x = df.iloc[: , 0:2]
y = df.iloc[:, -1]

# %%
x_train , x_test , y_train , y_test  = train_test_split(x, y , test_size = 0.2 , random_state = 2)

# %%
lor = LogisticRegression(solver = 'lbfgs')
lor.fit(x_train , y_train )
# Out:
# LogisticRegression()

# %%
y_pred = lor.predict(x_test)
accuracy_score(y_test , y_pred)
# Out:
# 0.9666666666666667

# %%
pd.DataFrame(confusion_matrix(y_test , y_pred))
# Out:
#     0  1  2
# 0  14  0  0
# 1   0  7  1
# 2   0  0  8

# %%
print(x_train.shape)
# Out:
# (120, 2)

# %%
print(x_train.columns)
# Out:
# Index(['sepal_length', 'petal_length'], dtype='object')

# %%
#prediction 

query = pd.DataFrame([[3.4, 2.7]] )
lor.predict_proba(query)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[7.25865651e-01, 2.73720718e-01, 4.13631316e-04]])

# %%
query
# Out:
#      0    1
# 0  3.4  2.7

# %%
lor.predict(query)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# !pip uninstall -y matplotlib
# !pip install --no-cache-dir --force-reinstall matplotlib
# Out:
# Found existing installation: matplotlib 3.11.0
# Uninstalling matplotlib-3.11.0:
#   Successfully uninstalled matplotlib-3.11.0
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Collecting numpy>=1.25 (from matplotlib)
#   Downloading numpy-2.5.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting packaging>=20.0 (from matplotlib)
#   Downloading packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.11.0-cp313-cp313-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 3.9 MB/s  0:00:02 eta 0:00:01
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.9 MB/s  0:00:00 eta 0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading numpy-2.5.1-cp313-cp313-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 3.9 MB/s  0:00:01 eta 0:00:01
# Downloading packaging-26.2-py3-none-any.whl (100 kB)
# Downloading pillow-12.3.0-cp313-cp313-macosx_11_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 3.9 MB/s  0:00:01m0:00:0100:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, cycler, python-dateutil, contourpy, matplotlib
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.3.2
#     Uninstalling pyparsing-3.3.2:
#       Successfully uninstalled pyparsing-3.3.2
#   Attempting uninstall: pillow━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [pyparsing]
#     Found existing installation: pillow 12.3.0━━━━━━━━━━━━━━━━  1/11 [pyparsing]
#     Uninstalling pillow-12.3.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [pyparsing]
#       Successfully uninstalled pillow-12.3.0━━━━━━━━━━━━━━━━━━  1/11 [pyparsing]
#   Attempting uninstall: packagingm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pillow]
#     Found existing installation: packaging 26.2━━━━━━━━━━━━━━━  2/11 [pillow]
#     Uninstalling packaging-26.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pillow]
#       Successfully uninstalled packaging-26.2━━━━━━━━━━━━━━━━━  2/11 [pillow]
#   Attempting uninstall: numpym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pillow]
#     Found existing installation: numpy 2.5.1━━━━━━━━━━━━━━━━━━  2/11 [pillow]
#     Uninstalling numpy-2.5.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pillow]
#       Successfully uninstalled numpy-2.5.1━━━━━━━━━━━━━━━━━━━━  2/11 [pillow]
#   Attempting uninstall: kiwisolver0m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [numpy]
#     Found existing installation: kiwisolver 1.5.0━━━━━━━━━━━━━  4/11 [numpy]
#     Uninstalling kiwisolver-1.5.0:90m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [numpy]
#       Successfully uninstalled kiwisolver-1.5.0━━━━━━━━━━━━━━━  4/11 [numpy]
#   Attempting uninstall: fonttools━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [numpy]
#     Found existing installation: fonttools 4.63.0━━━━━━━━━━━━━  4/11 [numpy]
#     Uninstalling fonttools-4.63.0:90m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [numpy]
#       Successfully uninstalled fonttools-4.63.0━━━━━━━━━━━━━━━  4/11 [numpy]
#   Attempting uninstall: cycler╸━━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#     Found existing installation: cycler 0.12.1━━━━━━━━━━━━━━━━  6/11 [fonttools]
#     Uninstalling cycler-0.12.1:91m╸━━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#       Successfully uninstalled cycler-0.12.1━━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#   Attempting uninstall: python-dateutil━━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#     Found existing installation: python-dateutil 2.9.0.post0━━  6/11 [fonttools]
#     Uninstalling python-dateutil-2.9.0.post0:━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#       Successfully uninstalled python-dateutil-2.9.0.post0━━━━  6/11 [fonttools]
#   Attempting uninstall: contourpym╸━━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#     Found existing installation: contourpy 1.3.3━━━━━━━━━━━━━━  6/11 [fonttools]
#     Uninstalling contourpy-1.3.3:m╸━━━━━━━━━━━━━━━━━━  6/11 [fonttools]
#       Successfully uninstalled contourpy-1.3.3━━━━━━━━━━━━━━━━  6/11 [fonttools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [matplotlib]1 [matplotlib]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.18.4 requires matplotlib<=3.10,>=3.5, but you have matplotlib 3.11.0 which is incompatible.
# ydata-profiling 4.18.4 requires numpy<2.4,>=1.22, but you have numpy 2.5.1 which is incompatible.
# numba 0.62.1 requires numpy<2.4,>=1.22, but you have numpy 2.5.1 which is incompatible.
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 numpy-2.5.1 packaging-26.2 pillow-12.3.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 six-1.17.0
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(x.values , y.values , lor , legend  = 2)

#dding axes annotations 

plt.xlabel('sepal length [cm]')
plt.ylabel ('petal_length [cm]')
plt.title('softmax on iris')

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
