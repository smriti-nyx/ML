# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../data/ushape.csv')

# %%
df.head()
# Out:
#    3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                  2.115098                 -0.046244
# 1                  0.882490                 -0.075756
# 2                 -0.055144                 -0.037332
# 3                  0.829545                 -0.539321
# 4                  2.112857                  0.662084
#
#    0.000000000000000000e+00
# 0                       1.0
# 1                       0.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
df.columns = ['x' , 'y' , 'target']

# %%
df.head()
# Out:
#           x         y  target
# 0  2.115098 -0.046244     1.0
# 1  0.882490 -0.075756     0.0
# 2 -0.055144 -0.037332     1.0
# 3  0.829545 -0.539321     1.0
# 4  2.112857  0.662084     1.0

# %%
x= df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x.shape
# Out:
# (99, 2)

# %%
plt.scatter(x.iloc[:,0] , x.iloc[:,1] , c= y)
#non linear relationship bw the features is portrayed below :

# %%
from sklearn.model_selection import train_test_split 
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 2 )

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()

# %%
lor.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.values , y.astype('int').values  ,lor , legend =2) # added .values suffix since x is a panda dataframe and not a numpy array
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
y_pred = lor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import cross_val_score
np.mean(cross_val_score(lor , x, y , scoring = 'accuracy' , cv = 10))
# Out:
# np.float64(0.8300000000000001)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.95

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3 , include_bias = False)
x_trf = poly.fit_transform(x)

# %%
np.mean(cross_val_score(lor , x_trf , y, scoring = 'accuracy' , cv = 10))
# Out:
# np.float64(0.9099999999999999)

# %%
def plot_decison_boundary(x , y , degree = 1):

    poly = PolynomialFeatures(degree=degree)
    x_trf = poly.fit_transform(x)

    lor = LogisticRegression()
    lor.fit(x_trf , y)

    accuracy = np.mean(cross_val_score(lor, x_trf , y ,scoring = 'accuracy' , cv = 10 ))


    a = np.arange(start = x.iloc[:,0].min() -1 , stop = x.iloc[:,0].max() +1 , step = 0.01)
    b = np.arange(start = x.iloc[:,1].min() -1 , stop = x.iloc[:,1].max() +1 , step = 0.01)

    XX ,YY = np.meshgrid(a,b)
   


    input_array=np.array([XX.ravel(),YY.ravel()]).T

    labels=lor.predict(poly.transform(input_array))
    
    plt.contourf(XX,YY,labels.reshape(XX.shape),alpha=0.5)
    plt.scatter(x.iloc[:,0],x.iloc[:,1], c=y)
    plt.title('Degree = {}, accuracy is {}'.format(degree,np.round(accuracy,4)))

# %%
plot_decison_boundary(x,y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
plot_decison_boundary(x,y, degree =2 )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
plot_decison_boundary(x,y , degree = 3) #best so far
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
plot_decison_boundary(x,y , degree = 4)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
