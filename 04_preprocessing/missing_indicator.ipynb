# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.impute import SimpleImputer,MissingIndicator

# %%
df = pd.read_csv('titanic_train.csv' , usecols = ['Age' , 'Fare' , 'Survived'])

# %%
df.sample(10)
# Out:
#      Survived   Age     Fare
# 522         0   NaN   7.2250
# 384         0   NaN   7.8958
# 668         0  43.0   8.0500
# 330         1   NaN  23.2500
# 834         0  18.0   8.3000
# 94          0  59.0   7.2500
# 394         1  24.0  16.7000
# 396         0  31.0   7.8542
# 571         1  53.0  51.4792
# 869         1   4.0  11.1333

# %%
x = df.drop(columns = ['Survived'])
y = df['Survived']

# %%
x_train , x_test , y_train , y_test = train_test_split(x, y , test_size = 0.2, random_state = 2)

# %%
x_train.head()
# Out:
#       Age     Fare
# 30   40.0  27.7208
# 10    4.0  16.7000
# 873  47.0   9.0000
# 182   9.0  31.3875
# 876  20.0   9.8458

# %%
si = SimpleImputer()
#missing values got replaced by mean values using simple imputer
x_train_trf = si.fit_transform(x_train)
x_test_trf = si.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(x_train_trf , y_train)
y_pred = clf.predict(x_test_trf)

# %%
x_train_trf
# Out:
# array([[ 40.        ,  27.7208    ],
#        [  4.        ,  16.7       ],
#        [ 47.        ,   9.        ],
#        ...,
#        [ 71.        ,  49.5042    ],
#        [ 29.78590426, 221.7792    ],
#        [ 29.78590426,  25.925     ]], shape=(712, 2))

# %%
y_train
# Out:
# 30     0
# 10     1
# 873    0
# 182    0
# 876    0
#       ..
# 534    0
# 584    0
# 493    0
# 527    0
# 168    0
# Name: Survived, Length: 712, dtype: int64

# %%
y_pred.shape
# Out:
# (179,)

# %%
y_test.shape
# Out:
# (179,)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.6145251396648045

# %%
#with missing indicator

# %%
from sklearn.linear_model import LogisticRegression

# %%
mi = MissingIndicator()
clf = LogisticRegression()

x_train_trf2 = mi.fit_transform(x_train)
x_test_trf2 = mi.transform(x_test)

# %%
x_train_trf2
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
x_train['Age_na'] = x_train_trf2
x_train.sample(10)
# Out:
#       Age      Fare  Age_na
# 539  22.0   49.5000   False
# 485   NaN   25.4667    True
# 53   29.0   26.0000   False
# 499  24.0    7.7958   False
# 56   21.0   10.5000   False
# 125  12.0   11.2417   False
# 211  35.0   21.0000   False
# 886  27.0   13.0000   False
# 842  30.0   31.0000   False
# 325  36.0  135.6333   False

# %%
#the above data form is what missing inidcator does . rest of the process is same

# %%
x_test_trf2
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
x_test['Age_na'] = x_test_trf2

# %%
x_test_trf2
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
# ...

# %%
x_test.sample(10)
# Out:
#       Age      Fare  Age_na
# 447  34.0   26.5500   False
# 438  64.0  263.0000   False
# 692   NaN   56.4958    True
# 862  48.0   25.9292   False
# 711   NaN   26.5500    True
# 702  18.0   14.4542   False
# 458  50.0   10.5000   False
# 591  52.0   78.2667   False
# 721  17.0    7.0542   False
# 830  15.0   14.4542   False

# %%
si = SimpleImputer() #to fill the missing values in the age column

x_train_trf2 = si.fit_transform(x_train)
x_test_trf2 = si.transform(x_test)

# %%
clf = LogisticRegression()
clf.fit(x_train_trf2 , y_train)
y_pred2 = clf.predict(x_test_trf2)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.6312849162011173

# %%
x_test_trf2
# Out:
# array([[ 42.        ,  26.2875    ,   0.        ],
#        [ 21.        ,   8.05      ,   0.        ],
#        [ 24.        ,  65.        ,   0.        ],
#        [ 28.        ,  56.4958    ,   0.        ],
#        [ 17.        ,   7.925     ,   0.        ],
#        [ 30.        ,   7.8958    ,   0.        ],
#        [ 80.        ,  30.        ,   0.        ],
#        [ 25.        ,   7.25      ,   0.        ],
#        [ 50.        , 133.65      ,   0.        ],
#        [ 25.        ,  26.        ,   0.        ],
#        [ 35.        ,  26.        ,   0.        ],
#        [ 35.        ,  90.        ,   0.        ],
#        [ 55.        ,  16.        ,   0.        ],
#        [ 29.78590426,  56.4958    ,   1.        ],
#        [ 29.78590426,  56.4958    ,   1.        ],
#        [ 19.        ,   7.8542    ,   0.        ],
#        [ 29.78590426,  15.2458    ,   1.        ],
#        [ 49.        ,   0.        ,   0.        ],
# ...

# %%
#simple integrated has this added feature too

si = SimpleImputer(add_indicator = True)

# %%
x_train =si.fit_transform(x_train)
x_test = si.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(x_train_trf2 , y_train)
y_pred3 = clf.predict(x_test_trf2)

from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred3)
# Out:
# 0.6312849162011173
